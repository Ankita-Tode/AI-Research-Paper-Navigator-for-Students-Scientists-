# %%
# !pip install streamlit

# %%
# !pip install pypdf

# %%
# !streamlit run sementicsearch.py

# %%
# !streamlit run gap.py

# %%
# !streamlit run contribution.py

# %%
# !streamlit run methodology.py

# %%
# !streamlit run summary.py

# %%
# !streamlit run textsplitter.py

# %%
# !streamlit run textextraction.py
